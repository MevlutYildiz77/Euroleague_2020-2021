# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %% [markdown]
# Read data from file

# %%
df=pd.read_excel("Euroleague 2020-2021.xlsx")
df
# Out:
#               Player                       Club  Number Position  \
# 0    Abalde, Alberto                Real Madrid       6  Forward
# 1      Abrines, Alex               FC Barcelona      21  Forward
# 2     Alocen, Carlos                Real Madrid      12    Guard
# 3      Amaize, Robin           FC Bayern Munich      15  Forward
# 4    Anderson, James               Anadolu Efes      23  Forward
# ..               ...                        ...     ...      ...
# 289  Zakharov, Denis        Zenit St Petersburg       3    Guard
# 290     Zipser, Paul           FC Bayern Munich      16  Forward
# 291      Zizic, Ante  Maccabi Playtika Tel Aviv      23   Center
# 292   Zoosman, Yovel  Maccabi Playtika Tel Aviv      50    Guard
# 293   Zubkov, Andrey        Zenit St Petersburg      20  Forward
#
#                  Nation  Age  Height  Games  Min  Pts  ...  Blocks(Fv)  \
# 0                 Spain   25     202     39  761  281  ...           0
# ...

# %% [markdown]
# Display the first 5 row from dataset

# %%
df.head()
# Out:
#             Player              Club  Number Position   Nation  Age  Height  \
# 0  Abalde, Alberto       Real Madrid       6  Forward    Spain   25     202
# 1    Abrines, Alex      FC Barcelona      21  Forward    Spain   27     198
# 2   Alocen, Carlos       Real Madrid      12    Guard    Spain   20     194
# 3    Amaize, Robin  FC Bayern Munich      15  Forward  Germany   26     188
# 4  Anderson, James      Anadolu Efes      23  Forward      USA   31     198
#
#    Games  Min  Pts  ...  Blocks(Fv) Blocks(Fv)_avg Blocks(Ag) Blocks(Ag)_avg  \
# 0     39  761  281  ...           0           0.00          6           0.15
# 1     39  730  237  ...           8           0.21          7           0.18
# 2     28  376  110  ...           2           0.07          4           0.14
# 3      9   51    4  ...           0           0.00          1           0.11
# 4     41  622  172  ...           6           0.15          3           0.07
#
# ...

# %% [markdown]
# Display the general knowledge about the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 294 entries, 0 to 293
# Data columns (total 32 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Player          294 non-null    object
#  1   Club            294 non-null    object
#  2   Number          294 non-null    int64
#  3   Position        294 non-null    object
#  4   Nation          294 non-null    object
#  5   Age             294 non-null    int64
#  6   Height          294 non-null    int64
#  7   Games           294 non-null    int64
#  8   Min             294 non-null    int64
#  9   Pts             294 non-null    int64
#  10  Pts_avg         294 non-null    float64
#  11  2FG             294 non-null    object
#  12  3FG             294 non-null    object
#  13  FT              294 non-null    object
#  14  Rebounds        294 non-null    int64
#  15  Rebounds_avg    294 non-null    float64
#  16  Assists         294 non-null    int64
# ...

# %% [markdown]
# Display the statistical result for the numerical data from the dataset

# %%
df.describe()
# Out:
#            Number         Age      Height       Games          Min  \
# count  294.000000  294.000000  294.000000  294.000000   294.000000
# mean    17.578231   27.578231  199.710884   24.057823   450.500000
# std     15.975846    4.565676    8.186067   11.480807   305.773386
# min      0.000000   17.000000  178.000000    1.000000     2.000000
# 25%      7.000000   25.000000  193.000000   15.000000   168.500000
# 50%     13.000000   28.000000  200.000000   28.000000   471.000000
# 75%     23.000000   31.000000  205.000000   33.000000   700.750000
# max     99.000000   40.000000  223.000000   41.000000  1200.000000
#
#               Pts     Pts_avg    Rebounds  Rebounds_avg     Assists  ...  \
# count  294.000000  294.000000  294.000000    294.000000  294.000000  ...
# mean   177.105442    6.254810   65.227891      2.378503   39.163265  ...
# std    147.231397    4.174004   54.368033      1.539595   44.840337  ...
# ...

# %% [markdown]
# Display the statistical result for the object data from the dataset

# %%
df.describe(include="object")
# Out:
#                  Player                  Club Position Nation  2FG  3FG   FT
# count               294                   294      294    294  294  294  294
# unique              293                    18        3     41  255  216  222
# top     Westermann, Leo  Khimki Moscow Region    Guard    USA  0/0  0/0  0/0
# freq                  2                    20      124     81   11   34   25
